# %% [markdown]
# ## Which is the greatest nation in tennis in the years 2019-2021
# ## Which are the top 5 players in the tennis ranking in the period 2019-2021

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = (12, 9)
plt.rcParams['font.size'] = 12

sns.set_theme(style="darkgrid")

pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## Load the data
# The data is filtered in the period between 2019 to 2021

# %%
df_2019 = pd.read_csv("data/atp_matches_2019.csv")
df_2020 = pd.read_csv("data/atp_matches_2020.csv")
df_2021 = pd.read_csv("data/atp_matches_2021.csv")

seasons = [df_2019, df_2020, df_2021]
df_full = pd.concat(seasons)

# check whether we have same number of columns
# assert len(df_2019.columns) == len(df_full.columns)

df_full.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2019-M020     Brisbane    Hard         32             A      20181231
# 1  2019-M020     Brisbane    Hard         32             A      20181231
# 2  2019-M020     Brisbane    Hard         32             A      20181231
# 3  2019-M020     Brisbane    Hard         32             A      20181231
# 4  2019-M020     Brisbane    Hard         32             A      20181231
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stWon l_2ndWon  \
# 0        300     105453          2.0          NaN  ...     34.0     20.0
# 1        299     106421          4.0          NaN  ...     36.0      7.0
# 2        298     105453          2.0          NaN  ...     15.0      6.0
# 3        297     104542          NaN           PR  ...     38.0      9.0
# 4        296     106421          4.0          NaN  ...     46.0     19.0
#
#    l_SvGms l_bpSaved  l_bpFaced  winner_rank  winner_rank_points loser_rank  \
# 0     14.0      10.0       15.0          9.0              3590.0       16.0
# 1     10.0      10.0       13.0         16.0              1977.0      239.0
# 2      8.0       1.0        5.0          9.0              3590.0       40.0
# 3     11.0       4.0        6.0        239.0               200.0       31.0
# 4     15.0       2.0        4.0         16.0              1977.0       18.0
#
#   loser_rank_points   c
# 0            1977.0 NaN
# 1             200.0 NaN
# 2            1050.0 NaN
# 3            1298.0 NaN
# 4            1855.0 NaN
#
# [5 rows x 50 columns]

# %%
number_of_countries = df_full.groupby('winner_ioc')['winner_name'].count()
number_of_countries.head(10)
# Out:
# winner_ioc
# ALG      2
# ARG    322
# AUS    356
# AUT    109
# BAR      3
# BEL     77
# BIH     20
# BLR     82
# BOL     20
# BRA     37
# Name: winner_name, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15,7))
df_full.groupby('winner_ioc')['winner_name'].count().plot(ax=ax)
plt.xlabel('The country of the winner')
plt.ylabel("The number of wins")
plt.title('Which tennis nation wins the most')
# Out:
# Text(0.5, 1.0, 'Which tennis nation wins the most')

# %%
# here I present another method for finding name and country
data_year = df_full.groupby(['winner_ioc','winner_name']).size()
data_year
# Out:
# winner_ioc  winner_name
# ALG         Lamine Ouahab            2
# ARG         Diego Schwartzman      103
#             Facundo Bagnis          14
#             Federico Coria          22
#             Federico Delbonis       47
#                                   ...
# UZB         Denis Istomin            4
#             Jurabek Karimov          1
#             Sanjar Fayziev           1
# VEN         Luis David Martinez      1
# ZIM         Benjamin Lock            3
# Length: 375, dtype: int64

# %% [markdown]
# ## Removing NaN values

# %%
df_full.dropna(subset = ["winner_rank"], inplace=True)
df_full.dropna(subset = ["winner_id"], inplace=True)

# %%
#sorting the values vy winner rank
df_full.sort_values(['winner_rank'],ascending=True)
# Out:
#                             tourney_id                  tourney_name surface  \
# 693                           2020-560                       Us Open    Hard
# 279                           2020-580               Australian Open    Hard
# 152                           2019-580               Australian Open    Hard
# 1679                          2021-560                       Us Open    Hard
# 1678                          2021-540                     Wimbledon   Grass
# ...                                ...                           ...     ...
# 2656   2021-M-DC-2021-WG1-M-BEL-BOL-01  Davis Cup WG1 R1: BEL vs BOL    Clay
# 1413  2020-M-DC-2020-WG2-PO-INA-KEN-01  Davis Cup WG2 PO: INA vs KEN    Hard
# 1378  2020-M-DC-2020-WG1-PO-NOR-BAR-01  Davis Cup WG1 PO: NOR vs BAR    Hard
# 1421  2020-M-DC-2020-WG2-PO-MAR-VIE-01  Davis Cup WG2 PO: MAR vs VIE    Clay
# 2714   2021-M-DC-2021-WG2-M-SLO-PAR-01  Davis Cup WG2 R1: SLO vs PAR    Clay
#
#       draw_size tourney_level  tourney_date  match_num  winner_id  \
# 693         128             G      20200831        100     104925
# 279         128             G      20200120        212     104745
# 152         128             G      20190114        212     104925
# 1679        128             G      20210830        100     104925
# 1678        128             G      20210628        226     104925
# ...         ...           ...           ...        ...        ...
# 2656          4             D      20210918          2     123961
# 1413          4             D      20200306          2     105812
# 1378          4             D      20200306          4     206716
# 1421          4             D      20200306          4     209119
# 2714          4             D      20210917          2     210107
#
#       winner_seed winner_entry  ... l_1stWon l_2ndWon  l_SvGms l_bpSaved  \
# 693           1.0          NaN  ...     29.0     15.0     12.0      12.0
# 279           1.0          NaN  ...     83.0     14.0     21.0       7.0
# 152           1.0          NaN  ...     65.0     17.0     19.0      11.0
# 1679          1.0          NaN  ...     30.0     22.0     17.0       6.0
# 1678          1.0          NaN  ...     69.0     24.0     22.0       9.0
# ...           ...          ...  ...      ...      ...      ...       ...
# 2656          NaN          NaN  ...     39.0     18.0     14.0       8.0
# 1413          NaN          NaN  ...      NaN      NaN      NaN       NaN
# 1378          NaN          NaN  ...      9.0      9.0      7.0       2.0
# 1421          NaN          NaN  ...      NaN      NaN      NaN       NaN
# 2714          NaN          NaN  ...     26.0     12.0     12.0       8.0
#
#       l_bpFaced  winner_rank  winner_rank_points loser_rank loser_rank_points  \
# 693        19.0          1.0             10860.0      109.0             524.0
# 279         9.0          1.0             10235.0       26.0            1520.0
# 152        18.0          1.0              9135.0       19.0            1865.0
# 1679       14.0          1.0             11113.0      145.0             541.0
# 1678       15.0          1.0             12113.0        9.0            4468.0
# ...         ...          ...                 ...        ...               ...
# 2656       12.0       1332.0                 4.0      191.0             367.0
# 1413        NaN       1346.0                 3.0        NaN               NaN
# 1378        8.0       1564.0                 2.0        NaN               NaN
# 1421        NaN       1671.0                 1.0        NaN               NaN
# 2714       15.0       1758.0                 1.0        NaN               NaN
#
#               c
# 693   33.278576
# 279   33.631759
# 152         NaN
# 1679        NaN
# 1678        NaN
# ...         ...
# 2656        NaN
# 1413  28.616016
# 1378  19.293634
# 1421  17.938398
# 2714        NaN
#
# [6958 rows x 50 columns]

# %%
df_filtered = df_full[['tourney_name','winner_name','winner_ioc','winner_id','winner_rank','winner_rank_points','winner_hand']]
df_filtered
# Out:
#                       tourney_name         winner_name winner_ioc  winner_id  \
# 0                         Brisbane       Kei Nishikori        JPN     105453
# 1                         Brisbane     Daniil Medvedev        RUS     106421
# 2                         Brisbane       Kei Nishikori        JPN     105453
# 3                         Brisbane  Jo-Wilfried Tsonga        FRA     104542
# 4                         Brisbane     Daniil Medvedev        RUS     106421
# ...                            ...                 ...        ...        ...
# 2722  Davis Cup WG2 R1: THA vs DEN     August Holmgren        DEN     200416
# 2723  Davis Cup WG2 R1: THA vs DEN      Kasidit Samrej        THA     208937
# 2724  Davis Cup WG2 R1: TUR vs LAT    Altug Celikbilek        TUR     123795
# 2725  Davis Cup WG2 R1: TUR vs LAT           Cem Ilkel        TUR     117356
# 2726  Davis Cup WG2 R1: TUR vs LAT         Ergi Kirkin        TUR     144985
#
#       winner_rank  winner_rank_points winner_hand
# 0             9.0              3590.0           R
# 1            16.0              1977.0           R
# 2             9.0              3590.0           R
# 3           239.0               200.0           R
# 4            16.0              1977.0           R
# ...           ...                 ...         ...
# 2722        905.0                16.0           R
# 2723       1136.0                 8.0           R
# 2724        170.0               427.0           U
# 2725        176.0               408.0           R
# 2726        311.0               166.0           R
#
# [6958 rows x 7 columns]

# %% [markdown]
# ## Filtering the data frame for players that have achieved more than 8000 rank points

# %%
filtered_rank_points_df = df_filtered[df_filtered['winner_rank_points']>8000]
filtered_rank_points_df
# Out:
#                          tourney_name      winner_name winner_ioc  winner_id  \
# 30                               Doha   Novak Djokovic        SRB     104925
# 34                               Doha   Novak Djokovic        SRB     104925
# 42                               Doha   Novak Djokovic        SRB     104925
# 139                   Australian Open   Novak Djokovic        SRB     104925
# 145                   Australian Open   Novak Djokovic        SRB     104925
# ...                               ...              ...        ...        ...
# 2635  Davis Cup Finals SF: CRO vs SRB   Novak Djokovic        SRB     104925
# 2641   Davis Cup Finals F: RTF vs CRO  Daniil Medvedev        RUS     106421
# 2643  Davis Cup Finals SF: RTF vs GER  Daniil Medvedev        RUS     106421
# 2645  Davis Cup Finals QF: RTF vs SWE  Daniil Medvedev        RUS     106421
# 2647  Davis Cup Finals QF: SRB vs KAZ   Novak Djokovic        SRB     104925
#
#       winner_rank  winner_rank_points winner_hand
# 30            1.0              9045.0           R
# 34            1.0              9045.0           R
# 42            1.0              9045.0           R
# 139           1.0              9135.0           R
# 145           1.0              9135.0           R
# ...           ...                 ...         ...
# 2635          1.0             11540.0           R
# 2641          2.0              8640.0           R
# 2643          2.0              8640.0           R
# 2645          2.0              8640.0           R
# 2647          1.0             11540.0           R
#
# [322 rows x 7 columns]

# %% [markdown]
# ## My dataframe contains the number of wins by player from a specific country

# %%
country_of_players_df = filtered_rank_points_df.groupby('winner_ioc')['winner_id'].size()
country_of_players_df
# Out:
# winner_ioc
# AUT     18
# ESP     72
# GER      5
# GRE     14
# RUS     58
# SRB    155
# Name: winner_id, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15,7))
filtered_rank_points_df.groupby('winner_ioc')['winner_id'].count().plot(ax=ax)
plt.xlabel('Country')
plt.ylabel("The number of wins")
y = [0,160]
plt.yticks(np.arange(min(y), max(y)+1, 10))


plt.title('The origin of a player that win the most games in the period 2019 - 2021')
# Out:
# Text(0.5, 1.0, 'The origin of a player that win the most games in the period 2019 - 2021')

# %% [markdown]
# ##  Serbia is the country that has won the most trophies in period 2019-2022 (Thank you Nole!)

# %%
df_filtered.sort_values(['winner_rank'],ascending=True)
top_ten_players_df = df_filtered[(df_filtered['winner_rank']<10) &(df_filtered['winner_rank_points']>8000)] 
top_ten_players_df
# Out:
#                          tourney_name      winner_name winner_ioc  winner_id  \
# 30                               Doha   Novak Djokovic        SRB     104925
# 34                               Doha   Novak Djokovic        SRB     104925
# 42                               Doha   Novak Djokovic        SRB     104925
# 139                   Australian Open   Novak Djokovic        SRB     104925
# 145                   Australian Open   Novak Djokovic        SRB     104925
# ...                               ...              ...        ...        ...
# 2635  Davis Cup Finals SF: CRO vs SRB   Novak Djokovic        SRB     104925
# 2641   Davis Cup Finals F: RTF vs CRO  Daniil Medvedev        RUS     106421
# 2643  Davis Cup Finals SF: RTF vs GER  Daniil Medvedev        RUS     106421
# 2645  Davis Cup Finals QF: RTF vs SWE  Daniil Medvedev        RUS     106421
# 2647  Davis Cup Finals QF: SRB vs KAZ   Novak Djokovic        SRB     104925
#
#       winner_rank  winner_rank_points winner_hand
# 30            1.0              9045.0           R
# 34            1.0              9045.0           R
# 42            1.0              9045.0           R
# 139           1.0              9135.0           R
# 145           1.0              9135.0           R
# ...           ...                 ...         ...
# 2635          1.0             11540.0           R
# 2641          2.0              8640.0           R
# 2643          2.0              8640.0           R
# 2645          2.0              8640.0           R
# 2647          1.0             11540.0           R
#
# [322 rows x 7 columns]

# %% [markdown]
# ## I am left with 332 competitions won by players who are with ranking < 10

# %%
count_players_df = top_ten_players_df.groupby('winner_name')['winner_id'].size()
count_players_df
# Out:
# winner_name
# Alexander Zverev        5
# Daniil Medvedev        58
# Dominic Thiem          18
# Novak Djokovic        155
# Rafael Nadal           72
# Stefanos Tsitsipas     14
# Name: winner_id, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(15,7))
top_ten_players_df.groupby('winner_name')['winner_id'].count().plot(ax=ax)
plt.xlabel('Name of the player')
plt.ylabel("The number of wins")
y = [0,160]
plt.yticks(np.arange(min(y), max(y)+1, 10))


plt.title('Top 5 tennis players in the period 2019 - 2021')
# Out:
# Text(0.5, 1.0, 'Top 5 tennis players in the period 2019 - 2021')

# %% [markdown]
# ##  This graph shoes us the current top 5 tennis player in the tennis ranklist
# https://www.atptour.com/en/rankings/singles

# %% [markdown]
#  First place Noval Djokovic with 155 wins\
#  Second place Rafael Nadal with 72 wins\
#  Third place Daniil Medvedev with 58 wins
